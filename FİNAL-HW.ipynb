# %%
print("Bilgi yarışmamıza hoşgeldiniz")


a = input("1.Soru:Türkiye'nin başkenti neresidir?")
          
        
if a == "Ankara" or a == "ankara" or a == "ANKARA":
    print("Cevabınız Doğru +10 puan")
    print("-"*20)
else:
    print("Cevabınız Yanlış 0 puan ,****CEVAP=Ankara****")
    print("-"*20)
    
b = input("2.Soru: Güneşe en yakın 4. gezegen hangisidir?")

if b == "Mars" or b == "MARS" or b == "mars" :
    print("Cevabınız Doğru +10 puan")
    print("-"*20)
else:
    print("Cevabınız Yanlış 0 puan , ****CEVAP=Mars****")
    print("-"*20)
    
c = input("3.Soru: Dört tarafı denizle çevrili kara parçasının adı nedir?")

if c == "Ada" or c == "ada" or c == "ADA":
    print("Cevabınız Doğru +10 puan")
    print("-"*20)
else:
    print("Cevabınız Yanlış 0 puan , ****CEVAP= Ada****")
    print("-"*20)
    
d = input("4.Soru: Mustafa Kemal Atatürk'ü İstanbul'dan Samsun'a götüren vapurun adı nedir?")

if d == "Bandırma" or d == "BANDIRMA" or d== "bandırma" :
    print("Cevabınız Doğru +10 puan")
    print("-"*20)
else:
    print("Cevabınız Yanlış 0 puan , ****CEVAP=Bandırma****")
    print("-"*20)
    
y = input("5.Soru: Hangi sayının karesi 289'dur?")
       
if y == "17" :
    print("Cevabınız Doğru + 10 puan")
    print("-"*20)
else:
    print("Cevabınız Yanlış , ****CEVAP=17****")
    print("-"*20)
    
x = input("6.Soru: Manavgat Şelalesi hangi ilimizdedir?")
    
if x == "Antalya" or x== "ANTALYA" or x== "antalya":
    print("Cevabınız Doğru + 10 puan")
    print("-"*20)
else:
    print("Cevabınız Yanlış 0 puan , ****CEVAP=Antalya****")
    print("-"*20)    
    
t = input("7.Soru: Kimyasal formülü AU olan metalin ismi nedir?")
    
if t == "Altın" or t== "ALTIN" or t== "altın":
    print("Cevabınız Doğru + 10 puan")
    print("-"*20)
else:
    print("Cevabınız Yanlış 0 puan , ****CEVAP=Altın****")
    print("-"*20)    
    
r= input("8.Soru: Sıcaklığı ölçmek için kullanılan aletin adı nedir?")
    
if r == "Termometre" or r == "TERMOMETRE" or r == "termometre":
    print("Cevabınız Doğru + 10 puan")
    print("-"*20)
else:
    print("Cevabınız Yanlış 0 puan , ****CEVAP=Termometre****")
    print("-"*20)        

s = input("9.Soru: Türkiye'nin en büyük gölünün adı nedir?")
    
if s == "Van Gölü" or s == "VAN GÖLÜ" or s == "van gölü":
    print("Cevabınız Doğru + 10 puan")
    print("-"*20)
else:
    print("Cevabınız Yanlış 0 puan , ****CEVAP=Van Gölü****")
    print("-"*20)        
    
v = input("10.Soru: Alternatif akımı bulan bilim insanının tam ismi nedir?")
    
if v == "Nikola Tesla" or v == "NİKOLA TESLA" or v == "nikola tesla":
    print("Cevabınız Doğru + 10 puan")
    print("-"*20)
else:
    print("Cevabınız Yanlış 0 puan , ****CEVAP=Nikola Tesla****")
    print("-"*20)        
    
    
    


    
    
    
z = int(input("Lütfen toplam puanınızı giriniz = "))
if    0 <= z < 50 :
    print("BAŞARISIZ OLDUNUZ...")
    
elif  50 <= z <= 100 :
    print("TEBRİKLER...")
    
else :
    print ("LÜTFEN GEÇERLİ BİR PUAN GİRİNİZ")
# Out:
# Bilgi yarışmamıza hoşgeldiniz
# 1.Soru:Türkiye'nin başkenti neresidir?ANKARA
# Cevabınız Doğru +10 puan
# --------------------
# 2.Soru: Güneşe en yakın 4. gezegen hangisidir?mars
# Cevabınız Doğru +10 puan
# --------------------
# 3.Soru: Dört tarafı denizle çevrili kara parçasının adı nedir?ada
# Cevabınız Doğru +10 puan
# --------------------
# 4.Soru: Mustafa Kemal Atatürk'ü İstanbul'dan Samsun'a götüren vapurun adı nedir?bandırma
# Cevabınız Doğru +10 puan
# --------------------
# 5.Soru: Hangi sayının karesi 289'dur?17
# Cevabınız Doğru + 10 puan
# --------------------
# 6.Soru: Manavgat Şelalesi hangi ilimizdedir?Antalya
# Cevabınız Doğru + 10 puan
# --------------------
# 7.Soru: Kimyasal formülü AU olan metalin ismi nedir?Altın
# Cevabınız Doğru + 10 puan
# --------------------
# 8.Soru: Sıcaklığı ölçmek için kullanılan aletin adı nedir?termometre
# Cevabınız Doğru + 10 puan
# --------------------
# 9.Soru: Türkiye'nin en büyük gölünün adı nedir?Van Gölü
# ...
